# %% [markdown]
# Operações Aritméticas

# %%
#soma
print(4+4)
#subtração
print(10-2)
#multiplicação  
print(5*2)
#divisão
print(16/2)
#potenciação    
print(2**3)
# Módulo
print(10%3)
# Out:
# 8
# 8
# 10
# 8.0
# 8
# 0

# %% [markdown]
# Função Type

# %%
print("ola")
# Out:
# ola
